# %% [markdown]
# Hey guys, this is V1.1 of our group assignment. Since different people will be coding this assignment explain every step of the code and be sure to stay consistent with variable names.
#
# I make variable names quite long and spell them out completely. It's intuitive and makes it easier when we start to re-organise cells

# %% [markdown]
# ## Opening packages

# %%
#Importatation of packages

import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# S:\Anaconda_3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# ## Opening data
#
# Note the conversion of the .xsl to .xlsx to update file structure. https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_excel.html

# %%
#Opening data

raw_data = pd.read_excel('cal_school_austin.xlsx')
raw_data.head(10)
# Out:
#    Observation Number  dist_cod       county                         district  \
# 0                   1     75119      Alameda               Sunol Glen Unified
# 1                   2     61499        Butte             Manzanita Elementary
# 2                   3     61549        Butte      Thermalito Union Elementary
# 3                   4     61457        Butte  Golden Feather Union Elementary
# 4                   5     61523        Butte         Palermo Union Elementary
# 5                   6     62042       Fresno          Burrel Union Elementary
# 6                   7     68536  San Joaquin            Holt Union Elementary
# 7                   8     63834         Kern              Vineland Elementary
# 8                   9     62331       Fresno         Orange Center Elementary
# 9                  10     67306   Sacramento      Del Paso Heights Elementary
#
#   gr_span  students    teachers  student_ratio  computers  comp_rat  \
# 0   KK-08       195   10.900000      17.889910         67  0.343590
# 1   KK-08       240   11.150000      21.524664        101  0.420833
# 2   KK-08      1550   82.900002      18.697226        169  0.109032
# 3   KK-08       243   14.000000      17.357143         85  0.349794
# 4   KK-08      1335   71.500000      18.671329        171  0.128090
# 5   KK-08       137    6.400000      21.406250         25  0.182482
# 6   KK-08       195   10.000000      19.500000         28  0.143590
# 7   KK-08       888   42.500000      20.894117         66  0.074324
# 8   KK-08       379   19.000000      19.947369         35  0.092348
# 9   KK-06      2247  108.000000      20.805555          0  0.000000
#
#    expenditure   calw_pct    meal_pct   engl_pct   wage_avg    read_scr  \
# 0  6384.911133   0.510200    2.040800   0.000000  22.690001  691.599976
# 1  5099.380859  15.416700   47.916698   4.583333   9.824000  660.500000
# 2  5501.954590  55.032299   76.322601  30.000002   8.978000  636.299988
# 3  7101.831055  36.475399   77.049202   0.000000   8.978000  651.900024
# 4  5235.987793  33.108601   78.427002  13.857677   9.080333  641.799988
# 5  5580.146973  12.318800   86.956497  12.408759  10.415000  605.700012
# 6  5253.331055  12.903200   94.623703  68.717949   6.577000  604.500000
# 7  4565.746094  18.806299  100.000000  46.959461   8.174000  605.500000
# 8  5355.548340  32.189999   93.139801  30.079157   7.385000  608.900024
# 9  5036.211426  78.994202   87.316399  40.275921  11.613333  611.900024
#
#      math_scr    test_scr
# 0  690.000000  690.799988
# 1  661.900024  661.200012
# 2  650.900024  643.599976
# 3  643.500000  647.700012
# 4  639.900024  640.849976
# 5  605.400024  605.550049
# 6  609.000000  606.750000
# 7  612.500000  609.000000
# 8  616.099976  612.500000
# 9  613.400024  612.650024

# %% [markdown]
# ## Box Plots
#
# https://seaborn.pydata.org/generated/seaborn.boxplot.html#seaborn.boxplot

# %%
#students

box_plot_student = sns.boxplot(x= raw_data['students'], data= raw_data, palette='Blues', showmeans=True)

plt.title('Boxplot for students')

plt.show()

# %%
#teachers

box_plot_student = sns.boxplot(x= raw_data['teachers'], data= raw_data, palette='Blues', showmeans=True)

plt.title('Boxplot for teachers')

plt.show()

# %%
#computers

box_plot_student = sns.boxplot(x= raw_data['computers'], data= raw_data, palette='Blues', showmeans=True)

plt.title('Boxplot for computers')

plt.show()

# %%
#calw_pct

box_plot_student = sns.boxplot(x= raw_data['calw_pct'], data= raw_data, palette='Blues', showmeans=True)

plt.title('Boxplot for calwork participation')

plt.show()

# %%
#engl_pct

box_plot_student = sns.boxplot(x= raw_data['engl_pct'], data= raw_data, palette='Blues', showmeans=True)

plt.title('Boxplot for english learning participation')

plt.show()

# %%
#wage_avg

box_plot_student = sns.boxplot(x= raw_data['wage_avg'], data= raw_data, palette='Blues', showmeans=True)

plt.title('Boxplot for average income')

plt.show()

# %% [markdown]
# ## Correlation Heat Map
#
# https://seaborn.pydata.org/generated/seaborn.heatmap.html

# %% [markdown]
# #### School characteristics heat map

# %%
heat_map_1_variables=['students', 'teachers', 'student_ratio', 'computers', 'comp_rat', 'expenditure']

fig, heat_map_1 = plt.subplots()
sns.heatmap(raw_data[heat_map_1_variables].corr(), vmax= 1, vmin= -1, center= 0, square= True, annot= True, ax= heat_map_1, cmap= 'YlGnBu')

heat_map_1.set_title('School Characteristics Correlation Heat Map', fontweight= 'bold', fontsize= 13)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Demographic characteristics heat map

# %%
heat_map_2_variables=['calw_pct', 'meal_pct', 'engl_pct', 'wage_avg']

fig, heat_map_2 = plt.subplots()
sns.heatmap(raw_data[heat_map_2_variables].corr(), vmax= 1, vmin= -1, center= 0, square= True, annot= True, ax= heat_map_2, cmap= 'YlGnBu')

heat_map_2.set_title('Demographic Characteristics Correlation Heat Map', fontweight= 'bold', fontsize= 13)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Test score characteristics heat map

# %%
heat_map_3_variables=['read_scr', 'math_scr', 'test_scr']

fig, heat_map_3 = plt.subplots()
sns.heatmap(raw_data[heat_map_3_variables].corr(), vmax= 1, vmin= -1, center= 0, square= True, annot= True, ax= heat_map_3, cmap= 'YlGnBu')

heat_map_3.set_title('Test Score Characteristics Correlation Heat Map', fontweight= 'bold', fontsize= 13)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### All variable heat map

# %%
all_variables=['students', 'teachers', 'student_ratio', 'computers', 'comp_rat', 'expenditure', 'calw_pct', 'meal_pct', 'engl_pct', 'wage_avg', 'read_scr', 'math_scr', 'test_scr']

fig, heat_map_4 = plt.subplots()
sns.heatmap(raw_data[all_variables].corr(), vmax= 1, vmin= -1, center= 0, square= True, annot= False, ax= heat_map_4, cmap= 'YlGnBu')

heat_map_4.set_title('All Variables Correlation Heat Map', fontweight= 'bold', fontsize= 13)

plt.show()

# %% [markdown]
# ## Scatterplot matrix
#
# https://seaborn.pydata.org/generated/seaborn.pairplot.html

# %%
scatterplot_matrix_1 = sns.pairplot(raw_data[all_variables], kind= 'reg', plot_kws = {'scatter_kws' :{'color': sns.color_palette('Blues')[-1], 'alpha': 0.4}})

plt.tight_layout()
plt.show()

# %% [markdown]
# ## -----------------------------------------------------

# %% [markdown]
# ## -----------------------------------------------------

# %% [markdown]
# ## -----------------------------------------------------

# %% [markdown]
# ## Test code

# %%
fig, ax = plt.subplots()
variables=['students', 'teachers', 'student_ratio', 'computers', 'comp_rat', 'expenditure']
cmap = sns.diverging_palette(220, 10, as_cmap= True)
sns.heatmap(raw_data[variables].corr(), vmax= 1, vmin= -1, center= 0, square= True, annot= True, ax= ax,  cmap= cmap)
ax.set_title('Correlation heat map', fontweight= 'bold', fontsize= 13)
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots()
variables=['students', 'teachers', 'student_ratio', 'computers', 'comp_rat', 'expenditure']
sns.heatmap(raw_data[variables].corr(), vmax= 1, vmin= -1, center= 0, square= True, annot= True, ax= ax,  cmap= 'YlGnBu')
ax.set_title('Correlation heat map', fontweight= 'bold', fontsize= 13)
plt.tight_layout()
plt.show()
